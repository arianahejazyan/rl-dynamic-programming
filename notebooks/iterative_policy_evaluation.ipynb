# %% [markdown]
# ## Iterative Policy Evaluation, for estimating $V\approx v_\pi$

# %% [markdown]
# ### Import Libraries

# %%
import os
import sys
import gymnasium as gym
import numpy as np
from gymnasium.envs.toy_text import TaxiEnv
from pathlib import Path

project_dir = Path(Path.cwd().parent)
sys.path.append(str(project_dir))
sys.path.append(str(project_dir / "src"))

from src import *

# %% [markdown]
# ### Create Enviornment

# %%
env = TaxiEnv()

# %%
# policy = random_stochastic_policy(env)
policy = random_deterministic_policy(env)

# %%
V = iterative_policy_evaluation(env, policy, False, max_iteration=10000)
V
# Out:
# Policy Evaluation: 10000iter [00:27, 364.29iter/s, delta=1.00e+01]
# array([ -19999., -100000.,  -19999.,  -10000.,  -19999.,  -10000.,
#         -10000., -100000.,  -10000., -100000.,  -10000.,  -99983.,
#        -100000., -100000.,  -99982.,  -10000.,  -99982.,  -99991.,
#         -20000.,  -10001., -100000., -100000., -100000., -100000.,
#         -20000.,  -10000.,  -10000.,  -19999.,  -10001., -100000.,
#         -10001., -100000.,  -99991., -100000.,  -99983., -100000.,
#        -100000., -100000.,  -10000.,  -10002., -100000.,  -99973.,
#         -19999.,  -10000.,  -10000.,  -99991.,  -10000., -100000.,
#        -100000.,  -10000.,  -19999.,  -99973.,  -99973., -100000.,
#         -99991., -100000.,  -10000., -100000., -100000.,  -10000.,
#        -100000.,  -99982.,  -20000.,  -99991.,  -10000.,  -10000.,
#         -10001.,  -10000., -100000.,  -10000.,  -20000.,  -99974.,
#         -10000.,  -99991., -100000., -100000.,  -10000., -100001.,
# ...
